# %% [markdown]
# # Python Open Lab

# %% [markdown]
# ## Beautiful Soup

# %% [markdown]
# $*$ Beautiful Soup is a library that makes it easy to scrape information from web pages. It sits atop an HTML or XML parser, providing Pythonic idioms for iterating, searching, and modifying the parse tree.
#
# $*$ Check out official documentation here: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
#example of use

import bs4
import urllib.request

#make a string to record where
loc='https://library.columbia.edu/index.html'

#create the page object using urllib
page=urllib.request.urlopen(loc)



#create the soup object
soup=bs4.BeautifulSoup(page,'html.parser')

# %%
# now lets check out some methods
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <!-- <meta http-equiv="keywords" content=""> -->
#   <!-- <meta http-equiv="description" content=""> -->
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <title>
#    Libraries Home | Columbia University Libraries
#   </title>
#   <script>
#    var CUL = {};
# var LDPD = {};
#   </script>
#   <link href="//cdn.cul.columbia.edu/ldpd-toolkit/build/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="//cdn.cul.columbia.edu/ldpd-toolkit/build/css/bootstrap-responsive.min.css" rel="stylesheet"/>
#   <link href="//cdn.cul.columbia.edu/ldpd-toolkit/build/css/ldpd-toolkit.min.css" rel="stylesheet"/>
#   <link href="/etc/clientlibs/shared/shared-v2.css" rel="stylesheet" type="text/css"/>
#   <link href="/etc/clientlibs/shared/cul-base-v1.css" rel="stylesheet" type="text/css"/>
#   <link href="/etc/designs/libraryweb/libraryweb-v2/clientlibs.css" rel="stylesheet" type="text/css"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML5 elements -->
#   <!--[if lt IE 9]>
#     <script src="http://html5shim.googlecode.com/svn/trunk/html5.js"></script>
#     <![endif]-->
#   <link href="/etc/designs/libraryweb/libraryweb-v2/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <link href="/etc/designs/libraryweb/libraryweb-v2/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <!-- If present, insert page-specific head content from the Page Properties dialog -->
#   <meta content="he96LlPwbGKltsjmUJdEMU_4QTOClje1ubB-gzg0eSQ" name="google-site-verification">
#    <!-- GA Code for library.columbia.edu -->
#    <script type="text/javascript">
#     var _gaq = _gaq || [];
#       _gaq.push(['_setAccount', 'UA-21810005-3']);
#       _gaq.push(['_setDomainName', 'columbia.edu']);
#       _gaq.push(['_trackPageview']);
#
#       (function() {
#         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#       })();
#    </script>
#   </meta>
#  </head>
#  <script type="text/javascript">
#   CULqs_bestbets_log_datasource = 'lweb_widget';
#  </script>
#  <body class="is-home">
#   <div class="container" id="outer-container">
#    <div id="banner_outer">
#     <header>
#      <h1 class="hide">
#       CUL - Main Content
#      </h1>
#      <div class="row">
#       <div class="span12">
#        <div class="row" id="inner-headline">
#         <aside>
#          <h2 class="hide">
#           CUL - Banner
#          </h2>
#          <div class="span9 nomar doubletop" id="banner">
#           <div class="layout_inheritedbanner inheritedbanner-v1 parbase">
#            <a href="https://library.columbia.edu/index.html">
#             <img alt="Columbia University Libraries" class="banner" src="/content/dam/templates/libraryweb/banners/banner_cul.png" title="Columbia University Libraries"/>
#            </a>
#           </div>
#          </div>
#          <div class="span3 hidden-phone doubletop" id="spotlight">
#           <div class="layout_inheritedspotlight inheritedspotlight-v1 parbase">
#            <a href="https://library.columbia.edu/research/askalibrarian.html">
#             <img alt="Spotlight" class="spotlight" src="/content/dam/libraryweb/homepage/spotlight/2013/Ask a Librarian.jpg" title="Spotlight"/>
#            </a>
#            <span class="hidden inheritedspotlight-metadata" data-is-home-page-content="true">
#            </span>
#           </div>
#          </div>
#         </aside>
#        </div>
#       </div>
#      </div>
#     </header>
#    </div>
#    <nav>
#     <h1 class="hide">
#      CUL - NAV
#     </h1>
#     <div class="navbar well-mini" id="culnav">
#      <div class="navbar-inner square-all">
#       <div class="container">
#        <div class="pull-right span3 nomar hide" id="culnav-right">
#         Thursday October 25th, 2018
#        </div>
#        <h2 class="brand hidden-desktop pull-left">
#         Navigation
#        </h2>
#        <a class="btn btn-navbar" data-target="#culnav-collapse" data-toggle="collapse">
#         <span class="icon-bar">
#         </span>
#         <span class="icon-bar">
#         </span>
#         <span class="icon-bar">
#         </span>
#        </a>
#        <div class="nav-collapse collapse" id="culnav-collapse">
#         <ul class="nav" id="culnav-main">
#          <!-- id=menu -->
#          <li>
#           <a href="https://library.columbia.edu/index.html">
#            <i class="icon-home">
#            </i>
#           </a>
#          </li>
#          <li class="divider-vertical">
#          </li>
#          <li class="dropdown ">
#           <a class="dropdown-toggle" data-toggle="dropdown" href="https://library.columbia.edu/locations.html">
#            Locations
#            <b class="caret">
#            </b>
#           </a>
#           <ul class="dropdown-menu">
#            <li>
#             <a href="https://hours.library.columbia.edu">
#              <strong>
#               Hours
#              </strong>
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/map.html">
#              <strong>
#               Map
#              </strong>
#             </a>
#            </li>
#            <li class="divider">
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/avery.html">
#              Avery Architectural &amp; Fine Arts Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.barnard.edu/">
#              Barnard College Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/burke.html">
#              Burke Library At Union Theological Seminary
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/business.html">
#              Business &amp; Economics Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/butler.html">
#              Butler Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/chrdr.html">
#              Center For Human Rights Documentation &amp; Research
#             </a>
#            </li>
#            <li>
#             <a href="https://ctl.columbia.edu/">
#              Columbia Center for Teaching &amp; Learning
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/ccoh.html">
#              Columbia Center For Oral History
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/cuarchives.html">
#              Columbia University Archives
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/dhc.html">
#              Digital Humanities Center
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/music/music-lab.html">
#              Digital Music Lab
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/dsc.html">
#              Digital Science Center
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/dssc.html">
#              Digital Social Science Center
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/eastasian.html">
#              East Asian Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/global.html">
#              Global Studies
#             </a>
#            </li>
#            <li>
#             <a href="http://library.cumc.columbia.edu/">
#              Health Sciences Library
#             </a>
#            </li>
#            <li>
#             <a href="http://www.jtsa.edu/library">
#              Jewish Theological Seminary Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/journalism.html">
#              Journalism Library
#             </a>
#            </li>
#            <li>
#             <a href="http://www.law.columbia.edu/library/">
#              Law Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/lehman.html">
#              Lehman Social Sciences Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/math.html">
#              Mathematics Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/undergraduate.html">
#              Milstein Undergraduate Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/music.html">
#              Music &amp; Arts Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/rbml.html">
#              Rare Book &amp; Manuscript Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/science-engineering.html">
#              Science &amp; Engineering Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/social-work.html">
#              Social Work Library
#             </a>
#            </li>
#            <li>
#             <a href="https://library.tc.columbia.edu/">
#              Teachers College Library
#             </a>
#            </li>
#            <li class="divider">
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/libraries.html">
#              <strong>
#               Expanded View »
#              </strong>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="divider-vertical">
#          </li>
#          <li class="dropdown ">
#           <a class="dropdown-toggle" data-toggle="dropdown" href="https://library.columbia.edu/find.html">
#            Find
#            <b class="caret">
#            </b>
#           </a>
#           <ul class="dropdown-menu">
#            <li>
#             <a href="https://academiccommons.columbia.edu/">
#              Academic Commons
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/resolve/lweb0106">
#              Archival Collections
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/find/request/borrow-direct.html">
#              Borrow Direct
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/resolve/lweb0049">
#              Citation Finder
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/resolve/clio">
#              CLIO: Columbia Libraries Catalog
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/find/reserves.html">
#              Course Reserves
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/resolve/lweb0051">
#              Databases
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/find/digital-collections.html">
#              Digital Collections &amp; Exhibitions
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/find/eresources.html">
#              E-Resources
#             </a>
#            </li>
#            <li>
#             <a href="https://geodata.library.columbia.edu">
#              GeoData @ Columbia
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/locations/usgd.html">
#              Government Documents
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/find/request/ill.html">
#              Interlibrary Loan
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/find/catalogs.html">
#              Other Library Catalogs
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/resolve/lweb0004">
#              Recommend A Title for Purchase
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/find/request.html">
#              Request Items &amp; Services
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/find/request/document-delivery.html">
#              Scan &amp; Deliver
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/find/web-archives.html">
#              Web Archives at Columbia
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/resolve/AMS7418">
#              WorldCat
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="divider-vertical">
#          </li>
#          <li class="dropdown">
#           <a class="dropdown-toggle" data-toggle="dropdown" href="https://library.columbia.edu/research.html">
#            Research Support
#            <b class="caret">
#            </b>
#           </a>
#           <ul class="dropdown-menu">
#            <li>
#             <a href="https://library.columbia.edu/research/askalibrarian.html">
#              Ask A Librarian
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/research/citation-management.html">
#              Manage Citations
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/resolve/lweb0094">
#              Research Consultations
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/subject-guides.html">
#              Research Guides
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/research.html">
#              Research Support
#             </a>
#            </li>
#            <li>
#             <a href="https://academiccommons.columbia.edu/upload">
#              Share Your Research
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/staff/subject-specialists-by-subject.html">
#              Subject Specialists
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/research/tutorials.html">
#              Tutorials
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/research/workshops.html">
#              Workshops
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="divider-vertical">
#          </li>
#          <li class="dropdown">
#           <a class="dropdown-toggle" data-toggle="dropdown" href="https://library.columbia.edu/services.html">
#            Services
#            <b class="caret">
#            </b>
#           </a>
#           <ul class="dropdown-menu">
#            <li>
#             <a href="https://library.columbia.edu/services/using-libraries.html">
#              Accessing Columbia Libraries
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/using-libraries/alumni.html">
#              Alumni
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/borrowing.html">
#              Borrowing
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/butler-lockers.html">
#              Butler Library Lockers
#             </a>
#            </li>
#            <li>
#             <a href="https://copyright.columbia.edu/">
#              Copyright Advisory Services
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/digital-scholarship.html">
#              Digital Scholarship
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/preservation/reproductions.html">
#              Digitization &amp; Copying Services
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/disability.html">
#              Disability Services
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/faculty.html">
#              Faculty
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/grad-students.html">
#              Graduate Students
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/preservation.html">
#              Preservation Division
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/research-data-services.html">
#              Research Data Services
#             </a>
#            </li>
#            <li>
#             <a href="https://roomreservations.cul.columbia.edu/">
#              Room Reservation
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/study-spaces.html">
#              Study Spaces
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/undergraduates.html">
#              Undergraduates
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/services/using-libraries.html">
#              Visitors
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="divider-vertical">
#          </li>
#          <li class="dropdown">
#           <a class="dropdown-toggle" data-toggle="dropdown" href="https://library.columbia.edu/technology.html">
#            Computers &amp; Technology
#            <b class="caret">
#            </b>
#           </a>
#           <ul class="dropdown-menu">
#            <li>
#             <a href="https://library.columbia.edu/technology.html">
#              Computing &amp; Technology Services
#             </a>
#            </li>
#            <li>
#             <a href="http://policylibrary.columbia.edu/acceptable-use-it-resources-network-and-computing-policy">
#              Computing &amp; Usage Policies
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/technology/printing.html">
#              Printing Services
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/technology/tools.html">
#              Research Tools
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/technology/scanning.html">
#              Scanning Services
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="divider-vertical">
#          </li>
#          <li class="dropdown">
#           <a class="dropdown-toggle" data-toggle="dropdown" href="https://library.columbia.edu/about.html">
#            About
#            <b class="caret">
#            </b>
#           </a>
#           <ul class="dropdown-menu">
#            <li>
#             <a href="https://library.columbia.edu/about.html">
#              About Columbia University Libraries
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/bts.html">
#              Behind the Scenes
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/staff/classified.html">
#              Departments &amp; Services
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/about/facts.html">
#              Fast Facts
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/about/jobs-internships.html">
#              Job &amp; Internship Opportunities
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/about/awards.html">
#              Libraries Awards
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/about/policies.html">
#              Policies
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/staff.html">
#              Staff
#             </a>
#            </li>
#            <li>
#             <a href="https://strategicdirections.library.columbia.edu">
#              Strategic Directions
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/about/student_advisory_committee.html">
#              Student Library Advisory Committee
#             </a>
#            </li>
#            <li>
#             <a href="https://library.columbia.edu/about/university-librarian.html">
#              University Librarian
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </div>
#        <!--/culnav-collapse-->
#       </div>
#      </div>
#     </div>
#    </nav>
#    <div id="alert-container">
#    </div>
#    <div id="main">
#     <div class="row">
#      <div class="span9" id="primary">
#       <section>
#        <h1 class="hide">
#         Libraries Home
#        </h1>
#        <div id="culqswh">
#         Loading Quicksearch...
#        </div>
#        <article>
#         <div class="layout_homecarousel imagecarousel-v1 parbase">
#          <div class="cul-imagecarousel cul-component carousel slide cul-carousel " data-interval="6000" id="unique-carousel-id-layout_homecarousel">
#           <div id="carousel-controls">
#            <i class="icon-play icon-white" data-control="cycle">
#            </i>
#            <i class="icon-pause icon-white" data-control="pause">
#            </i>
#           </div>
#           <ol class="carousel-indicators">
#            <li class="active" data-slide-to="0" data-target="#unique-carousel-id-layout_homecarousel">
#            </li>
#            <li data-slide-to="1" data-target="#unique-carousel-id-layout_homecarousel">
#            </li>
#            <li data-slide-to="2" data-target="#unique-carousel-id-layout_homecarousel">
#            </li>
#            <li data-slide-to="3" data-target="#unique-carousel-id-layout_homecarousel">
#            </li>
#            <li data-slide-to="4" data-target="#unique-carousel-id-layout_homecarousel">
#            </li>
#            <li data-slide-to="5" data-target="#unique-carousel-id-layout_homecarousel">
#            </li>
#           </ol>
#           <div class="carousel-inner">
#            <div class="item active">
#             <a data-event-action="Click Carousel Image Link" data-event-category="Home Page" data-event-label="/content/libraryweb/services/digital-scholarship/open-access-week-2018.html" data-event-track="true" href="https://library.columbia.edu/services/digital-scholarship/open-access-week-2018.html">
#              <img alt="Carousel image 0" src="/content/dam/libraryweb/homepage/carousel/2018/OCT_OAWeek.png"/>
#             </a>
#             <div class="hero-carousel carousel-caption">
#              <p>
#               Columbia Libraries hosts workshops &amp; panel discussion on open access on 10/25
#               <a class="lc sc nodec" data-event-action="Click Carousel Read More Link" data-event-category="Home Page" data-event-label="/content/libraryweb/services/digital-scholarship/open-access-week-2018.html" data-event-track="true" data-rel="tooltip" href="https://library.columbia.edu/services/digital-scholarship/open-access-week-2018.html">
#                … Read More »
#               </a>
#              </p>
#             </div>
#            </div>
#            <div class="item">
#             <a data-event-action="Click Carousel Image Link" data-event-category="Home Page" data-event-label="/content/libraryweb/locations/cuarchives/resources/media.html" data-event-track="true" href="https://library.columbia.edu/locations/cuarchives/resources/media.html">
#              <img alt="Carousel image 1" src="/content/dam/libraryweb/homepage/carousel/2018/OCT_ArchivesMonth_UA.jpg"/>
#             </a>
#             <div class="hero-carousel carousel-caption">
#              <p>
#               Celebrate Archives Month! Explore new audio &amp; video content from the University Archives
#               <a class="lc sc nodec" data-event-action="Click Carousel Read More Link" data-event-category="Home Page" data-event-label="/content/libraryweb/locations/cuarchives/resources/media.html" data-event-track="true" data-rel="tooltip" href="https://library.columbia.edu/locations/cuarchives/resources/media.html">
#                … Read More »
#               </a>
#              </p>
#             </div>
#            </div>
#            <div class="item">
#             <a data-event-action="Click Carousel Image Link" data-event-category="Home Page" data-event-label="/content/libraryweb/research/workshops.html" data-event-track="true" href="https://library.columbia.edu/research/workshops.html">
#              <img alt="Carousel image 2" src="/content/dam/libraryweb/homepage/carousel/2018/AUG_Workshops.jpg"/>
#             </a>
#             <div class="hero-carousel carousel-caption">
#              <p>
#               Learn the latest methods &amp; software from Columbia Libraries' expert staff
#               <a class="lc sc nodec" data-event-action="Click Carousel Read More Link" data-event-category="Home Page" data-event-label="/content/libraryweb/research/workshops.html" data-event-track="true" data-rel="tooltip" href="https://library.columbia.edu/research/workshops.html">
#                … Read More »
#               </a>
#              </p>
#             </div>
#            </div>
#            <div class="item">
#             <a data-event-action="Click Carousel Image Link" data-event-category="Home Page" data-event-label="https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e24-64bd5cc5-0164-dc72bec3-0000619fevents%40columbia.edu&amp;returnlinkurl=/content/libraryweb/index&amp;returnlinktext=Libraries%20Home" data-event-track="true" href="https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e24-64bd5cc5-0164-dc72bec3-0000619fevents%40columbia.edu&amp;returnlinkurl=/content/libraryweb/index&amp;returnlinktext=Libraries%20Home">
#              <img alt="Carousel image 3" src="/content/dam/libraryweb/homepage/carousel/2018/OCT_TransformingBroadway.jpg"/>
#             </a>
#             <div class="hero-carousel carousel-caption">
#              <p>
#               The magic of early 20th-century Broadway comes to life in new RBML exhibit
#               <a class="lc sc nodec" data-event-action="Click Carousel Read More Link" data-event-category="Home Page" data-event-label="https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e24-64bd5cc5-0164-dc72bec3-0000619fevents%40columbia.edu&amp;returnlinkurl=/content/libraryweb/index&amp;returnlinktext=Libraries%20Home" data-event-track="true" data-rel="tooltip" href="https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e24-64bd5cc5-0164-dc72bec3-0000619fevents%40columbia.edu&amp;returnlinkurl=/content/libraryweb/index&amp;returnlinktext=Libraries%20Home">
#                … Read More »
#               </a>
#              </p>
#             </div>
#            </div>
#            <div class="item">
#             <a data-event-action="Click Carousel Image Link" data-event-category="Home Page" data-event-label="https://blogs.cul.columbia.edu/spotlights/category/we-are-your-library/" data-event-track="true" href="https://blogs.cul.columbia.edu/spotlights/category/we-are-your-library/">
#              <img alt="Carousel image 4" src="/content/dam/libraryweb/homepage/carousel/2018/AUG_WeAreYourLibrary.jpg"/>
#             </a>
#             <div class="hero-carousel carousel-caption">
#              <p>
#               We are your library! Meet the people who make the Libraries dynamic &amp; sustainable
#               <a class="lc sc nodec" data-event-action="Click Carousel Read More Link" data-event-category="Home Page" data-event-label="https://blogs.cul.columbia.edu/spotlights/category/we-are-your-library/" data-event-track="true" data-rel="tooltip" href="https://blogs.cul.columbia.edu/spotlights/category/we-are-your-library/">
#                … Read More »
#               </a>
#              </p>
#             </div>
#            </div>
#            <div class="item">
#             <a data-event-action="Click Carousel Image Link" data-event-category="Home Page" data-event-label="https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e28-64ebaf5d-0164-f0d24990-00003444events%40columbia.edu&amp;returnlinkurl=/content/libraryweb/news/events&amp;returnlinktext=Events" data-event-track="true" href="https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e28-64ebaf5d-0164-f0d24990-00003444events%40columbia.edu&amp;returnlinkurl=/content/libraryweb/news/events&amp;returnlinktext=Events">
#              <img alt="Carousel image 5" src="/content/dam/libraryweb/homepage/carousel/2018/OCT_PersianBookbinding.jpg"/>
#             </a>
#             <div class="hero-carousel carousel-caption">
#              <p>
#               RBML exhibit explores bookbinding in 15th-century Iran as a site for creative expression
#               <a class="lc sc nodec" data-event-action="Click Carousel Read More Link" data-event-category="Home Page" data-event-label="https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e28-64ebaf5d-0164-f0d24990-00003444events%40columbia.edu&amp;returnlinkurl=/content/libraryweb/news/events&amp;returnlinktext=Events" data-event-track="true" data-rel="tooltip" href="https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e28-64ebaf5d-0164-f0d24990-00003444events%40columbia.edu&amp;returnlinkurl=/content/libraryweb/news/events&amp;returnlinktext=Events">
#                … Read More »
#               </a>
#              </p>
#             </div>
#            </div>
#           </div>
#           <a class="left carousel-control" data-slide="prev" href="#unique-carousel-id-layout_homecarousel">
#            «
#           </a>
#           <a class="right carousel-control" data-slide="next" href="#unique-carousel-id-layout_homecarousel">
#            »
#           </a>
#          </div>
#          <script type="text/javascript">
#           if(typeof CUL !== 'undefined' && typeof CUL.startCarousels !== 'undefined') {
#                     CUL.startCarousels();
#                 }
#          </script>
#         </div>
#        </article>
#        <div class="row-fluid">
#         <div class="span12">
#          <div class="row-fluid">
#           <div class="span6" id="divHomepageContent1">
#            <article>
#             <div class="well-primary">
#              <div class="layout_par_main_1 parsys">
#               <div class="text-v2 parbase section">
#                <div class="cul-image cul-component">
#                 <div class="cul-text cul-component">
#                  <h3 class="home">
#                   <a href="https://library.columbia.edu/news/events.html">
#                    Events
#                    <span class="pull-right" style="color: #08c;">
#                     »
#                    </span>
#                   </a>
#                  </h3>
#                 </div>
#                </div>
#               </div>
#               <div class="eventslist-v1 section">
#                <div class="cul-eventslist cul-component" data-initialized="false" data-show-full-details="false" id="eventslist_v1">
#                 <div class="event-data-container">
#                  <p>
#                   Loading events...
#                  </p>
#                 </div>
#                </div>
#                <script type="text/javascript">
#                 //When the component is rendered, (on page load or eventlist component dialog update), set the event request parameters on the component's DOM object
#     (function()
#     {
# 		var objEventsRequestParameters = {};
#         var strUniqueComponentId = "";
#         var aryEventsRequestCULCategories = [];
#         var aryEventsRequestLocations = [];
#         var aryEventsRequestAudiences = [];
#         var aryEventsRequestTypes = [];
#         var aryEventsRequestTypesExclude = [];
#         var strEventsRequestStartDate = "";
#         var strEventsRequestEndDate = "";
#         var intMaxEventsToDisplay = 0;
#         var strReturnLinkURL = "";
#         var strReturnLinkText = "";
#         var strFormat = "";
#
#         strUniqueComponentId = "eventslist_v1";
#         aryEventsRequestCULCategories[0] = "org/cu_libraries"
#         aryEventsRequestTypesExclude[0] = "Workshop"
#         aryEventsRequestTypesExclude[1] = "Training"
#
#     strEventsRequestStartDate = "";
#     strEventsRequestEndDate = "";
#     intMaxEventsToDisplay = 7;
#     strReturnLinkURL = "/content/libraryweb/index";
#     strReturnLinkText = "Libraries Home";
#     strFormat = "homepage";
#
#     objEventsRequestParameters["componentId"] = strUniqueComponentId;
#     objEventsRequestParameters["culcategories"] = aryEventsRequestCULCategories;
#     objEventsRequestParameters["locations"] = aryEventsRequestLocations;
#     objEventsRequestParameters["audiences"] = aryEventsRequestAudiences;
#     objEventsRequestParameters["types"] = aryEventsRequestTypes;
#     objEventsRequestParameters["typesExclude"] = aryEventsRequestTypesExclude;
#     objEventsRequestParameters["startDate"] = strEventsRequestStartDate;
#     objEventsRequestParameters["endDate"] = strEventsRequestEndDate;
#     objEventsRequestParameters["maxEventsToDisplay"] = intMaxEventsToDisplay;
#     objEventsRequestParameters["returnLinkURL"] = strReturnLinkURL;
#     objEventsRequestParameters["returnLinkText"] = strReturnLinkText;
#     objEventsRequestParameters["format"] = strFormat;
#
#     document.getElementById("eventslist_v1").initParams = objEventsRequestParameters;
#
#     }());//End anonymous function to set eventlist params
#
#
#
#     //If the component is being rendered after the $(document).ready() event has already fired (as in when the component dialog has just been updated)...
#     if (typeof AEM != 'undefined')
#     {
# 		//...we need to call the function directly to reload the list.
#         AEM.populateEventsListComponents();
#     }
#                </script>
#               </div>
#               <div class="text-v2 parbase section">
#                <div class="cul-image cul-component">
#                 <div class="cul-text cul-component">
#                  <p>
#                   <a class="lc sc" href="https://library.columbia.edu/news/events.html">
#                    more events »
#                   </a>
#                  </p>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </article>
#           </div>
#           <div class="span6" id="divHomepageContent2">
#            <article>
#             <div class="well-primary">
#              <div class="layout_par_main_2 parsys">
#               <div class="text-v2 parbase section">
#                <div class="cul-image cul-component">
#                 <div class="cul-text cul-component">
#                  <h3 class="home">
#                   <a href="https://library.columbia.edu/news.html">
#                    News
#                    <span class="pull-right" style="color: #08c;">
#                     »
#                    </span>
#                   </a>
#                  </h3>
#                 </div>
#                </div>
#               </div>
#               <div class="homepagenews-v1 section">
#                <div class="cul-homepagenews cul-component">
#                 <ul class="hide-bullets">
#                  <li>
#                   <div>
#                    <a class="homepromohead" href="https://library.columbia.edu/news/libraries/2018/2018-03-27_1968_Student_Engagement.html">
#                     Activism in the Archives
#                    </a>
#                    <br/>
#                    <span class="release-blurb">
#                     This semester’s events and exhibits to commemorate the global revolutions of 1968 inspired Columbia students to engage directly with archival materials from the era and explore the legacies of young activists not unlike themselves
#                    </span>
#                    …
#                    <div class="clearfix">
#                    </div>
#                   </div>
#                  </li>
#                  <li>
#                   <div>
#                    <a class="homepromohead" href="https://library.columbia.edu/news/libraries/2018/2018-03-27_Faculty_Work_Digital_Dante.html">
#                     The Divine Connector
#                    </a>
#                    <br/>
#                    <span class="release-blurb">
#                     In partnership with Columbia Professor Teodolinda Barolini, the Libraries is working to digitally connect illuminated manuscripts, artwork, sound recordings, commentary, and more related to the study of Dante Alighieri’s The Divine Comedy
#                    </span>
#                    …
#                    <div class="clearfix">
#                    </div>
#                   </div>
#                  </li>
#                  <li>
#                   <div>
#                    <a class="homepromohead" href="https://library.columbia.edu/news/libraries/2018/2018-03-27_Web_Archiving.html">
#                     Countering Impermanence
#                    </a>
#                    <br/>
#                    <span class="release-blurb">
#                     In addition to building its own web archives – all of which are publicly accessible – the Libraries collects collaboratively with peer institutions and partners to ensure the capture and preservation of a highly ephemeral research source
#                    </span>
#                    …
#                    <div class="clearfix">
#                    </div>
#                   </div>
#                  </li>
#                 </ul>
#                 <p>
#                  <a class="lc sc" href="https://library.columbia.edu/news.html">
#                   read more »
#                  </a>
#                 </p>
#                </div>
#               </div>
#              </div>
#             </div>
#            </article>
#           </div>
#          </div>
#          <!--/row-->
#         </div>
#        </div>
#        <!--/row-->
#       </section>
#      </div>
#      <!--/span9-->
#      <div class="span3" id="secondary">
#       <aside>
#        <h1 class="hide">
#         Sidebar
#        </h1>
#        <div class="well sidebar-nav" id="divHomepageSidebar">
#         <div class="layout_par_sidebar parsys">
#          <div class="widgetbox-v2 section">
#           <div class="cul-widgetbox cul-component">
#            <nav>
#             <h2 class="hide">
#              Quicklinks
#             </h2>
#             <ul class="nav nav-list nopad">
#              <li class="nav-header">
#               Quicklinks
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Help" data-event-track="true" href="https://library.columbia.edu/help.html">
#                <i class="icon-flag">
#                </i>
#                Help
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Hours" data-event-track="true" href="https://hours.library.columbia.edu">
#                <i class="icon-time">
#                </i>
#                Hours
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Maps &amp; Directions" data-event-track="true" href="https://library.columbia.edu/locations/map.html">
#                <i class="icon-map-marker">
#                </i>
#                Maps &amp; Directions
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Ask a Librarian" data-event-track="true" href="https://library.columbia.edu/research/askalibrarian.html">
#                <i class="icon-question-sign">
#                </i>
#                Ask a Librarian
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Library Staff" data-event-track="true" href="https://library.columbia.edu/staff.html">
#                <i class="icon-user">
#                </i>
#                Library Staff
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="FAQ" data-event-track="true" href="https://library.columbia.edu/help/faq.html">
#                <i class="icon-info-sign">
#                </i>
#                FAQ
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Course Reserves" data-event-track="true" href="https://library.columbia.edu/find/reserves.html">
#                <i class="icon-book">
#                </i>
#                Course Reserves
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Request Items" data-event-track="true" href="https://library.columbia.edu/find/request.html">
#                <i class="icon-star-empty">
#                </i>
#                Request Items
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Events" data-event-track="true" href="https://library.columbia.edu/news/events.html">
#                <i class="icon-calendar">
#                </i>
#                Events
#               </a>
#              </li>
#              <li class="divider">
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Alumni" data-event-track="true" href="https://library.columbia.edu/services/using-libraries/alumni.html">
#                <i class="icon-globe">
#                </i>
#                Alumni
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Job Seekers" data-event-track="true" href="https://library.columbia.edu/about/jobs-internships.html">
#                <i class="icon-briefcase">
#                </i>
#                Job Seekers
#               </a>
#              </li>
#              <li>
#               <a data-event-action="Click Sidebar Link" data-event-category="Home Page" data-event-label="Visitors" data-event-track="true" href="https://library.columbia.edu/services/using-libraries.html">
#                <i class="icon-plane">
#                </i>
#                Visitors
#               </a>
#              </li>
#              <li class="divider">
#              </li>
#             </ul>
#            </nav>
#           </div>
#          </div>
#         </div>
#         <div class="center">
#          <a href="https://library.givenow.columbia.edu/?ac=HTNV">
#           <img alt="Donate to Columbia Libraries Now" src="/content/dam/libraryweb/homepage/Make-a-Gift-to-Columbia-Libraries.png" title="Donate to Columbia Libraries Now">
#           </img>
#          </a>
#         </div>
#        </div>
#        <!--/sidebar-nav-->
#       </aside>
#      </div>
#      <!--/span3-->
#     </div>
#     <!--/row-->
#    </div>
#    <!--//#main-->
#    <footer>
#     <div class="container">
#      <div class="row">
#       <div class="span12" id="site_footer">
#        <h1 class="hide">
#         CUL - Footer
#        </h1>
#        <div class="row">
#         <section>
#          <h2 class="hide">
#           General Contact
#          </h2>
#          <div class="span9">
#           <p>
#            535 West 114th St.
#                                 New York, NY 10027
#
#                                 Telephone
#                                 (212) 854-7309
#
#                                 Fax
#                                 (212) 854-9099
#           </p>
#           <p>
#            <a href="https://www.columbia.edu/content/copyright" title="© Columbia University Libraries">
#             Copyright
#            </a>
#            |
#            <a href="https://library.columbia.edu/about/policies.html">
#             Policies
#            </a>
#            |
#            <a class="feedback-popup" data-feedback-track-location="footer" href="#">
#             Suggestions &amp; Feedback
#            </a>
#            |
#            <!--<a href="#">Terms of Service</a> |-->
#            <a href="https://library.columbia.edu/services/lio.html">
#             Contact Us
#            </a>
#            |
#            <a href="https://library.columbia.edu/about.html">
#             About Us
#            </a>
#           </p>
#          </div>
#         </section>
#         <aside>
#          <h2 class="hide">
#           Etc.
#          </h2>
#          <div class="span3">
#           <p class="center">
#            <a class="thumbnail" data-rel="tooltip" href="https://twitter.com/columbialib" title="Follow us on Twitter">
#             <img alt="twitter" src="//cdn.cul.columbia.edu/ldpd-toolkit/build/img/twitter-icon-sq.png">
#             </img>
#            </a>
#            <a class="thumbnail" data-rel="tooltip" href="https://www.facebook.com/culibraries" title="Visit us on Facebook">
#             <img alt="facebook" src="//cdn.cul.columbia.edu/ldpd-toolkit/build/img/facebook-icon-sq.png">
#             </img>
#            </a>
#            <a class="thumbnail" data-rel="tooltip" href="https://foursquare.com/venue/135050" title="Visit us on Foursquare">
#             <img alt="foursquare" src="//cdn.cul.columbia.edu/ldpd-toolkit/build/img/foursquare-icon-sq.png">
#             </img>
#            </a>
#            <a class="thumbnail" data-rel="tooltip" href="https://blogs.cul.columbia.edu/spotlights/" title="Visit the CUL Blogs">
#             <img alt="culblogs" src="//cdn.cul.columbia.edu/ldpd-toolkit/build/img/culblog-icon-sq.png">
#             </img>
#            </a>
#            <a class="thumbnail" data-rel="tooltip" href="https://blogs.cul.columbia.edu/spotlights/feed/" title="Subscribe to our RSS Feed">
#             <img alt="rss" src="//cdn.cul.columbia.edu/ldpd-toolkit/build/img/rss-icon-sq.png">
#             </img>
#            </a>
#           </p>
#          </div>
#         </aside>
#        </div>
#        <!--/row-->
#       </div>
#       <!--/span12-->
#      </div>
#      <!--/row-->
#     </div>
#     <!--/container-->
#    </footer>
#   </div>
#   <!-- /outer-container -->
#   <!-- JS loaded last for speed -->
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.min.js">
#   </script>
#   <script>
#    window.jQuery || document.write('<script src="//cdn.cul.columbia.edu/ldpd-toolkit/build/js/jquery-1.7.2.min.js"><\/script>')
#   </script>
#   <script src="//cdn.cul.columbia.edu/ldpd-toolkit/build/js/bootstrap.min.js">
#   </script>
#   <script src="//cdn.cul.columbia.edu/ldpd-toolkit/build/js/ldpd-toolkit.min.js">
#   </script>
#   <script src="/etc/clientlibs/shared/shared-v2.js" type="text/javascript">
#   </script>
#   <script src="/etc/clientlibs/shared/cul-base-v1.js" type="text/javascript">
#   </script>
#   <script src="/etc/designs/libraryweb/libraryweb-v2/clientlibs.js" type="text/javascript">
#   </script>
#   <!-- CULQSW START -->
#   <script type="text/javascript">
#    <!--
#       CULh_width = 'fixed'; // fixed, fluid (default)
#       CULh_nobs = 1; // uncomment to NOT load our bootstrap javascript file and or use your own (v2.3.x required)
#       CULh_notk = 1; // uncomment to NOT load our ldpd-toolkit.js and or use your own.
#       CULqs_bestbets = 1;
#       //CULCDN = 'https://cdn.cul.columbia.edu/';
#     //-->
#   </script>
#   <script src="//cdn.cul.columbia.edu/ldpd-toolkit/widgets/typeahead.bundle.min.js">
#   </script>
#   <script src="//cdn.cul.columbia.edu/ldpd-toolkit/widgets/cultnbw.min.js">
#   </script>
#   <script src="//cdn.cul.columbia.edu/ldpd-toolkit/widgets/culqsw.min.js">
#   </script>
#   <!-- /CULQSW END -->
#  </body>
# </html>

# %%
#find and find_all
print(soup.find('title').get_text())
# Out:
# Libraries Home | Columbia University Libraries

# %%
for l in soup.find_all('a'):
    print(l.get('href')) #getting links
# Out:
# https://library.columbia.edu/index.html
# https://library.columbia.edu/research/askalibrarian.html
# None
# https://library.columbia.edu/index.html
# https://library.columbia.edu/locations.html
# https://hours.library.columbia.edu
# https://library.columbia.edu/locations/map.html
# https://library.columbia.edu/locations/avery.html
# https://library.barnard.edu/
# https://library.columbia.edu/locations/burke.html
# https://library.columbia.edu/locations/business.html
# https://library.columbia.edu/locations/butler.html
# https://library.columbia.edu/locations/chrdr.html
# https://ctl.columbia.edu/
# https://library.columbia.edu/locations/ccoh.html
# https://library.columbia.edu/locations/cuarchives.html
# https://library.columbia.edu/locations/dhc.html
# https://library.columbia.edu/locations/music/music-lab.html
# https://library.columbia.edu/locations/dsc.html
# https://library.columbia.edu/locations/dssc.html
# https://library.columbia.edu/locations/eastasian.html
# https://library.columbia.edu/locations/global.html
# http://library.cumc.columbia.edu/
# http://www.jtsa.edu/library
# https://library.columbia.edu/locations/journalism.html
# http://www.law.columbia.edu/library/
# https://library.columbia.edu/locations/lehman.html
# https://library.columbia.edu/locations/math.html
# https://library.columbia.edu/locations/undergraduate.html
# https://library.columbia.edu/locations/music.html
# https://library.columbia.edu/locations/rbml.html
# https://library.columbia.edu/locations/science-engineering.html
# https://library.columbia.edu/locations/social-work.html
# https://library.tc.columbia.edu/
# https://library.columbia.edu/locations/libraries.html
# https://library.columbia.edu/find.html
# https://academiccommons.columbia.edu/
# https://library.columbia.edu/resolve/lweb0106
# https://library.columbia.edu/find/request/borrow-direct.html
# https://library.columbia.edu/resolve/lweb0049
# https://library.columbia.edu/resolve/clio
# https://library.columbia.edu/find/reserves.html
# https://library.columbia.edu/resolve/lweb0051
# https://library.columbia.edu/find/digital-collections.html
# https://library.columbia.edu/find/eresources.html
# https://geodata.library.columbia.edu
# https://library.columbia.edu/locations/usgd.html
# https://library.columbia.edu/find/request/ill.html
# https://library.columbia.edu/find/catalogs.html
# https://library.columbia.edu/resolve/lweb0004
# https://library.columbia.edu/find/request.html
# https://library.columbia.edu/find/request/document-delivery.html
# https://library.columbia.edu/find/web-archives.html
# https://library.columbia.edu/resolve/AMS7418
# https://library.columbia.edu/research.html
# https://library.columbia.edu/research/askalibrarian.html
# https://library.columbia.edu/research/citation-management.html
# https://library.columbia.edu/resolve/lweb0094
# https://library.columbia.edu/subject-guides.html
# https://library.columbia.edu/research.html
# https://academiccommons.columbia.edu/upload
# https://library.columbia.edu/staff/subject-specialists-by-subject.html
# https://library.columbia.edu/research/tutorials.html
# https://library.columbia.edu/research/workshops.html
# https://library.columbia.edu/services.html
# https://library.columbia.edu/services/using-libraries.html
# https://library.columbia.edu/services/using-libraries/alumni.html
# https://library.columbia.edu/services/borrowing.html
# https://library.columbia.edu/services/butler-lockers.html
# https://copyright.columbia.edu/
# https://library.columbia.edu/services/digital-scholarship.html
# https://library.columbia.edu/services/preservation/reproductions.html
# https://library.columbia.edu/services/disability.html
# https://library.columbia.edu/services/faculty.html
# https://library.columbia.edu/services/grad-students.html
# https://library.columbia.edu/services/preservation.html
# https://library.columbia.edu/services/research-data-services.html
# https://roomreservations.cul.columbia.edu/
# https://library.columbia.edu/services/study-spaces.html
# https://library.columbia.edu/services/undergraduates.html
# https://library.columbia.edu/services/using-libraries.html
# https://library.columbia.edu/technology.html
# https://library.columbia.edu/technology.html
# http://policylibrary.columbia.edu/acceptable-use-it-resources-network-and-computing-policy
# https://library.columbia.edu/technology/printing.html
# https://library.columbia.edu/technology/tools.html
# https://library.columbia.edu/technology/scanning.html
# https://library.columbia.edu/about.html
# https://library.columbia.edu/about.html
# https://library.columbia.edu/bts.html
# https://library.columbia.edu/staff/classified.html
# https://library.columbia.edu/about/facts.html
# https://library.columbia.edu/about/jobs-internships.html
# https://library.columbia.edu/about/awards.html
# https://library.columbia.edu/about/policies.html
# https://library.columbia.edu/staff.html
# https://strategicdirections.library.columbia.edu
# https://library.columbia.edu/about/student_advisory_committee.html
# https://library.columbia.edu/about/university-librarian.html
# https://library.columbia.edu/services/digital-scholarship/open-access-week-2018.html
# https://library.columbia.edu/services/digital-scholarship/open-access-week-2018.html
# https://library.columbia.edu/locations/cuarchives/resources/media.html
# https://library.columbia.edu/locations/cuarchives/resources/media.html
# https://library.columbia.edu/research/workshops.html
# https://library.columbia.edu/research/workshops.html
# https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e24-64bd5cc5-0164-dc72bec3-0000619fevents%40columbia.edu&returnlinkurl=/content/libraryweb/index&returnlinktext=Libraries%20Home
# https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e24-64bd5cc5-0164-dc72bec3-0000619fevents%40columbia.edu&returnlinkurl=/content/libraryweb/index&returnlinktext=Libraries%20Home
# https://blogs.cul.columbia.edu/spotlights/category/we-are-your-library/
# https://blogs.cul.columbia.edu/spotlights/category/we-are-your-library/
# https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e28-64ebaf5d-0164-f0d24990-00003444events%40columbia.edu&returnlinkurl=/content/libraryweb/news/events&returnlinktext=Events
# https://library.columbia.edu/news/events/event.html?guid=CAL-00bb9e28-64ebaf5d-0164-f0d24990-00003444events%40columbia.edu&returnlinkurl=/content/libraryweb/news/events&returnlinktext=Events
# #unique-carousel-id-layout_homecarousel
# #unique-carousel-id-layout_homecarousel
# https://library.columbia.edu/news/events.html
# https://library.columbia.edu/news/events.html
# https://library.columbia.edu/news.html
# https://library.columbia.edu/news/libraries/2018/2018-03-27_1968_Student_Engagement.html
# https://library.columbia.edu/news/libraries/2018/2018-03-27_Faculty_Work_Digital_Dante.html
# https://library.columbia.edu/news/libraries/2018/2018-03-27_Web_Archiving.html
# https://library.columbia.edu/news.html
# https://library.columbia.edu/help.html
# https://hours.library.columbia.edu
# https://library.columbia.edu/locations/map.html
# https://library.columbia.edu/research/askalibrarian.html
# https://library.columbia.edu/staff.html
# https://library.columbia.edu/help/faq.html
# https://library.columbia.edu/find/reserves.html
# https://library.columbia.edu/find/request.html
# https://library.columbia.edu/news/events.html
# https://library.columbia.edu/services/using-libraries/alumni.html
# https://library.columbia.edu/about/jobs-internships.html
# https://library.columbia.edu/services/using-libraries.html
# https://library.givenow.columbia.edu/?ac=HTNV
# https://www.columbia.edu/content/copyright
# https://library.columbia.edu/about/policies.html
# #
# https://library.columbia.edu/services/lio.html
# https://library.columbia.edu/about.html
# https://twitter.com/columbialib
# https://www.facebook.com/culibraries
# https://foursquare.com/venue/135050
# https://blogs.cul.columbia.edu/spotlights/
# https://blogs.cul.columbia.edu/spotlights/feed/

# %%
# same as before but a different url
loc2='http://www.bloomberg.com/quote/SPX:IND'
page2=urllib.request.urlopen(loc2)
soup2=bs4.BeautifulSoup(page2,'html.parser')

print(soup2.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <title>
#    Bloomberg - Are you a robot?
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://assets.bwbx.io/font-service/css/BWHaasGrotesk-55Roman-Web,BWHaasGrotesk-75Bold-Web,BW%20Haas%20Text%20Mono%20A-55%20Roman/font-face.css" rel="stylesheet" type="text/css"/>
#   <style rel="stylesheet" type="text/css">
#    html, body, div, span, applet, object, iframe,
#         h1, h2, h3, h4, h5, h6, p, blockquote, pre,
#         a, abbr, acronym, address, big, cite, code,
#         del, dfn, em, img, ins, kbd, q, s, samp,
#         small, strike, strong, sub, sup, tt, var,
#         b, u, i, center,
#         dl, dt, dd, ol, ul, li,
#         fieldset, form, label, legend,
#         table, caption, tbody, tfoot, thead, tr, th, td,
#         article, aside, canvas, details, embed,
#         figure, figcaption, footer, header, hgroup,
#         menu, nav, output, ruby, section, summary,
#         time, mark, audio, video {
#             margin: 0;
#             padding: 0;
#             border: 0;
#             font-size: 100%;
#             font: inherit;
#             vertical-align: baseline;
#         }
#         /* HTML5 display-role reset for older browsers */
#         article, aside, details, figcaption, figure,
#         footer, header, hgroup, menu, nav, section {
#             display: block;
#         }
#         body {
#             line-height: 1;
#         }
#         ol, ul {
#             list-style: none;
#         }
#         blockquote, q {
#             quotes: none;
#         }
#         blockquote:before, blockquote:after,
#         q:before, q:after {
#             content: '';
#             content: none;
#         }
#         table {
#             border-collapse: collapse;
#             border-spacing: 0;
#         }
#
#         * {
#             box-sizing: border-box;
#         }
#
#         body {
#             background-color: #f2f2f2;
#             font-family: "BWHaasGrotesk-55Roman-Web";
#             line-height: 1.2;
#         }
#
#         .header {
#             margin: 0;
#             height: 60px;
#             width: 100%;
#             background-color: black;
#             color: white;
#             overflow-x: hidden;
#         }
#
#         .logo {
#             float: left;
#             margin: 0 20px;
#             height: 60px;
#             width: 140px;
#             background-image: url('data:image/svg+xml;base64,...');
#             background-repeat: no-repeat;
#             background-position: center;
#             font-size: 0;
#         }
#
#         .contact-us {
#             float: right;
#             margin: 0 20px;
#             line-height: 60px;
#             font-family: "BWHaasGrotesk-55Roman-Web";
#             font-size: 14px;
#             color: white;
#             text-decoration: underline;
#         }
#
#         .box {
#             margin: 30px auto;
#             padding: 30px;
#             width: 680px;
#             background-color: white;
#         }
#
#         @media (max-width:760px) {
#             .box {
#                 width: calc(100% - 20px);
#             }
#         }
#
#         .main__heading, .info__heading {
#             font-family: "BWHaasGrotesk-75Bold-Web";
#         }
#
#         .main__heading {
#             font-size: 19px;
#             padding-bottom: 9px;
#         }
#
#         .continue {
#             font-size: 18px;
#         }
#
#         #px-captcha {
#             margin-top: 20px;
#             min-height: 80px;
#         }
#
#         .info {
#             border-top: dotted 1px black;
#             padding-top: 9px;
#         }
#
#         .info + .info {
#             margin-top: 30px;
#         }
#
#         .info__link {
#             color: black;
#             text-decoration: underline;
#         }
#
#         .info__heading {
#             font-size: 16px;
#             line-height: 20px;
#             padding-bottom: 9px;
#         }
#
#         .info__text {
#             padding-bottom: 9px;
#         }
#
#         #block_uuid {
#             display: inline-block;
#             padding: 6px;
#             background-color: #f2f2f2;
#             font-family: "BW Haas Text Mono A-55 Roman";
#             font-size: 14px;
#         }
#   </style>
#   <script>
#    window._pxAppId = "PX8FCGYgk4";
#         window._pxJsClientSrc = "/8FCGYgk4/init.js";
#         window._pxFirstPartyEnabled = true;
#         window._pxHostUrl = "/8FCGYgk4/xhr";
#         window._pxreCaptchaTheme = "light";
#
#         function qs(name) {
#             var search = window.location.search;
#             var rx = new RegExp("[?&]" + name + "(=([^&#]*)|&|#|$)");
#             var match = rx.exec(search);
#             return match ? decodeURIComponent(match[2].replace(/\+/g, " ")) : null;
#         }
#   </script>
#  </head>
#  <body>
#   <header class="header">
#    <h1 class="logo">
#     Bloomberg
#    </h1>
#    <a class="contact-us" href="/feedback">
#     Need help? Contact us
#    </a>
#   </header>
#   <section class="box main">
#    <h2 class="main__heading">
#     We've detected unusual activity from your computer network
#    </h2>
#    <p class="continue">
#     To continue, please click the box below to let us know you're not a robot.
#    </p>
#    <div id="px-captcha">
#    </div>
#   </section>
#   <section class="box">
#    <section class="info">
#     <h3 class="info__heading">
#      Why did this happen?
#     </h3>
#     <p class="info__text">
#      Please make sure your browser supports JavaScript and cookies and that you are not blocking them from loading. For more information you can review our
#      <a class="info__link" href="/notices/tos">
#       Terms of Service
#      </a>
#      and
#      <a class="info__link" href="/notices/tos">
#       Cookie Policy
#      </a>
#      .
#     </p>
#    </section>
#    <section class="info">
#     <h3 class="info__heading">
#      Need Help?
#     </h3>
#     <p class="info__text">
#      For inquiries related to this message please
#      <a class="info__link" href="/feedback">
#       contact our support team
#      </a>
#      and provide the reference ID below.
#     </p>
#     <div id="block_uuid">
#      Block reference ID:
#     </div>
#    </section>
#   </section>
#   <script src="/8FCGYgk4/captcha/captcha.js?a=c&amp;m=0">
#   </script>
#   <script type="text/javascript">
#    document.getElementById("block_uuid").innerText = "Block reference ID: " + qs("uuid");
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## Positional Keywords or Parameters

# %%
def f(a,b):
    print('a is: ',a)
    print('b is: ',b)
    return

f(2,3)
# Out:
# a is:  2
# b is:  3

# %% [markdown]
# As expected the first parameter was passed into the parameter a and the second parameter into b. Now observe what happens if we invoke the function in this way:

# %%
f(b=10,a=0)
# Out:
# a is:  0
# b is:  10

# %% [markdown]
# What just happened? This time we specified the parameters by keyword, not by position. Of course we needed to know what the formal parameter names were but if we do, as long as we specifiy them by name, we don't have to worry about order. The only rule is that positional arguments come before keyword arguments in the function call. So for example this is okay:

# %%
f(6,b=12)
# Out:
# a is:  6
# b is:  12

# %%
f(b=12,6)
# Out:
#   File "<ipython-input-46-a7f8a95efa30>", line 1
#     f(b=12,6)
#           ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# What about f(6,a=12)? Try it! You'll see that this doesn't work because the argument 6 is passed into the parameter a and then we try to reassign it to 12.

# %% [markdown]
# ## Variable-Length-Postional Parameter
# In a function defintion these must come after the positional or keyword parameters.

# %%
def f(a,b=0,*args):
    print('a is: ',a)
    print('b is: ',b)
    print('args is: ',args)
    return

f(3,2,4,5,6)

# %% [markdown]
# The * in front of the parameter args makes it a variable-length-positional parameter. This means it absorbs any extra postional arguments and places them into a tuple called args. Specifying a parameter like this in a function definition gives the function caller the option of providing as many postional arguments as they want without breaking the function.

# %% [markdown]
# ## Keyword-Only Parameters:
# We can specifiy additional keyword parameters after the variable-length-positional parameter in a function definition. These parameters may only be specified by keyword, never positionally. For this reason we call these keyword-only parameters. Like this:

# %%
def g(a,b=0,*args,c=1,d=2):
    print('a is: ',a)
    print('b is: ',b)
    print('args is: ',args)
    print('c is: ',c)
    print('d is: ',d)
    return

g(1,2,3,4,5,d=100)
